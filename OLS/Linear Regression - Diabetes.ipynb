# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as skl
import numpy as np
# %matplotlib inline

# %%
# Setting up the dataset, shuffling and splitting for training
diabetes = skl.datasets.load_diabetes()
X = diabetes.data
y = diabetes.target
X, y = sk.utils.shuffle(X, y, random_state=1)
X = X[:, 2:3]
train_set_size = 250
X_train = X[:train_set_size]
X_test = X[train_set_size:]
y_train = y[:train_set_size]
y_test = y[train_set_size:]

# %%
# Let's look at what we've got
plt.scatter(X_train, y_train)
plt.scatter(X_test, y_test)
plt.xlabel('Data')
plt.ylabel('Target');

# %%
reg = skl.linear_model.LinearRegression()
reg.fit(X_train, y_train)
print ("coef :",reg.coef_)
print ("intercept :",reg.intercept_)
print ("RMSE training :", np.sqrt(metrics.mean_squared_error(y_train, reg.predict(X_train))))
print ("RMSE test :    ",np.sqrt(metrics.mean_squared_error(y_test, reg.predict(X_test))))

# Visualises dots and Plots the linear model (training)
plt.scatter(X_train, y_train,  color='violet')
plt.plot(X_train, reg.predict(X_train), color='blue', linewidth=3);
plt.xlabel('Data')
plt.ylabel('Target')
# Out:
# coef : [ 865.04619508]
# intercept : 151.179169728
# RMSE training : 61.6452822604
# RMSE test :     63.6179455555

# %%
# Visualises dots, where each dot represent a data exaple and corresponding teacher
plt.scatter(X_test, y_test,  color='violet')
# Plots the linear model
plt.plot(X_test, reg.predict(X_test), color='blue', linewidth=3);
plt.xlabel('Data')
plt.ylabel('Target');
